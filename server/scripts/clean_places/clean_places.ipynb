# %%
import pandas as pd
from pathlib import Path
PATH = r"C:\Users\kylec\OneDrive\Desktop\london-map"

# %%
csvs = list(Path(PATH).glob("*.csv"))
df = pd.concat((pd.read_csv(csv) for csv in csvs), ignore_index=True)
# FILTER OUT DUPLICATES BASED ON google_id
df = df.drop_duplicates(subset=["google_id"])
print(df.iloc[0])
# Out:
# query                  restaurant, SW12, Greater London, England, GB
# name                                                   Balham Social
# name_for_emails                                        Balham Social
# subtypes           Modern Indian restaurant, Bar, Catering food a...
# category                                    Modern Indian restaurant
#                                          ...
# place_id                                 ChIJZbfHf7sFdkgR6DW2wxcWs50
# google_id                      0x487605bb7fc7b765:0x9db31617c3b635e8
# cid                                             11363450576109450728
# kgmid                                                  /g/11n0j9rpbr
# reviews_id                                      -7083293497600100888
# Name: 0, Length: 65, dtype: object
