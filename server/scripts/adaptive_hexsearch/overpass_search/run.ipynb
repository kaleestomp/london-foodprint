# %%
from overpass_nearby import overpass_nearby_search, is_tile_saturated
import pandas as pd
COORDINATE = (51.456644, -0.143151)

# %%
results = overpass_nearby_search(
    lat=COORDINATE[0],
    lon=COORDINATE[1],
    radius_m=500,
    category="restaurant", # any OSM amenity value
    limit=20
)

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#   osm_type      osm_id             place_id                   name  \
# 0     node  9655728953  osm:node:9655728953            Camile Thai
# 1     node  2848406764  osm:node:2848406764           PizzaExpress
# 2     node  2121664891  osm:node:2121664891                 Brooke
# 3     node  2848407447  osm:node:2848407447           Bistro Union
# 4     node  9524662017  osm:node:9524662017      33 Abbeville Road
# 5     node  9502837317  osm:node:9502837317                Osteria
# 6     node  2641978068  osm:node:2641978068         La Bonne Heure
# 7     node  1314925506  osm:node:1314925506                 Mate's
# 8     node  1314925467  osm:node:1314925467  Pizzeria on the Green
#
#       amenity        lat       lon  distance_m  \
# 0  restaurant  51.454455 -0.139972      328.28
# 1  restaurant  51.454287 -0.140188      332.87
# 2  restaurant  51.454014 -0.140440      347.57
# 3  restaurant  51.454363 -0.139686      349.25
# 4  restaurant  51.453979 -0.140478      349.51
# ...
