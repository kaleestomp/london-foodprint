# %%
import sys
from pathlib import Path
from dotenv import load_dotenv, find_dotenv

# Resolve the repository root so the server package is importable from the notebook.
PROJECT_ROOT = None
for candidate in [Path.cwd(), *Path.cwd().parents]:
    if (candidate / "server").is_dir():
        PROJECT_ROOT = candidate
        break
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate the project root containing the server/ directory.")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Load local secrets from a file that is not committed to git.
load_dotenv(find_dotenv(".env.local", usecwd=True))
# Out:
# True

# %%
COORDINATE = (51.456644, -0.143151)
from server.scripts.get_seed_map_level2.request_aggregate.request_aggregate import request_aggregate
# --- Example: restaurants within 500 m of Clapham Common ---
results = await request_aggregate(
    latitude=COORDINATE[0],
    longitude=COORDINATE[1],
    radius=25, #Minimum 23m
)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[14], line 4
#       1 COORDINATE = (51.456644, -0.143151)
#       2 from server.scripts.get_seed_map_level2.request_aggregate.request_aggregate import request_aggregate
#       3 # --- Example: restaurants within 500 m of Clapham Common ---
# ----> 4 results = await request_aggregate(
#       5     latitude=COORDINATE[0],
#       6     longitude=COORDINATE[1],
#       7     radius=22,
#
# File c:\Users\kylec\OneDrive\Desktop\react_project\london-explorer\server\scripts\get_seed_map_level2\request_aggregate\request_aggregate.py:57, in request_aggregate(latitude, longitude, radius, cache)
#      52         print(
#      53             f"Places Aggregate request failed | status={resp.status_code} | ",
#      54             flush=True,
#      55         )
#      56         print(f"Response body: {resp.text}", flush=True)
# ---> 57     resp.raise_for_status()
#      59 payload = resp.json()
#      60 if cache:
#
# File c:\Users\kylec\OneDrive\Desktop\react_project\london-explorer\.venv\Lib\site-packages\httpx\_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://areainsights.googleapis.com/v1:computeInsights'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400

# %%
results
# Out:
# 0
