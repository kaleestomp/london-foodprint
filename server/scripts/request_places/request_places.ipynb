# %%
import sys, os, json
# Resolve project root so the server package is importable from the notebook
PROJECT_ROOT = os.path.abspath(os.path.join(os.path.dirname("__file__"), "../../.."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)
# Set your key here or export GOOGLE_PLACES_API_KEY in your shell
os.environ["GOOGLE_PLACES_API_KEY"] = "AIzaSyCU6_JJ9c7jCek9xbnCr8G9wfQc7leoA3k"
from server.scripts.request_places.request_places import nearby_search

# %%
# --- Example: restaurants within 500 m of central London (Trafalgar Square) ---
results = await nearby_search(
    latitude=51.5080,
    longitude=-0.1281,
    radius=100.0,
)

# %%
print(json.dumps(results, indent=2))
# Out:
# []
