# %%
import sys, json
from pathlib import Path
from dotenv import load_dotenv, find_dotenv
import pandas as pd

# Resolve the repository root so the server package is importable from the notebook.
PROJECT_ROOT = None
for candidate in [Path.cwd(), *Path.cwd().parents]:
    if (candidate / "server").is_dir():
        PROJECT_ROOT = candidate
        break
if PROJECT_ROOT is None:
    raise RuntimeError("Could not locate the project root containing the server/ directory.")
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# Load local secrets from a file that is not committed to git.
load_dotenv(find_dotenv(".env.local", usecwd=True))

from server.scripts.request_places.request_places import nearby_search

# %%
COORDINATE = (51.456644, -0.143151)
# --- Example: restaurants within 200 m of Clapham Common ---
results = await nearby_search(
    latitude=COORDINATE[0],
    longitude=COORDINATE[1],
    radius=200.0,
)

# %%
# print(json.dumps(results, indent=2))
results_df = pd.DataFrame(results)
results_df
# Out:
#                             id                         displayName  \
# 0  ChIJBZTVzRAFdkgRcNk6IdSfkds  500 Degrees Clapham South side ltd
#
#   primaryTypeDisplayName rating userRatingCount  \
# 0     Italian Restaurant   None            None
#
#                                             location  \
# 0  {'latitude': 51.456111299999996, 'longitude': ...
#
#                   shortFormattedAddress  \
# 0  71 Clapham Common South Side, London
#
#                                        googleMapsUri priceRange priceLevel  \
# 0  https://maps.google.com/?cid=15821602699368651...       None       None
#
#                          websiteUri businessStatus  \
# 0  https://500degreesbrixton.co.uk/    OPERATIONAL
#
#                                                types         primaryType
# 0  [italian_restaurant, restaurant, point_of_inte...  italian_restaurant
